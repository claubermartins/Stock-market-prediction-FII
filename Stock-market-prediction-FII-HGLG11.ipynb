# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction-FII/blob/master/Stock-market-prediction-FII-HGLG11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Requirement already satisfied: inflection in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ##**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-ecfa8110-8f87-49f9-b2a4-06e8d32da244" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecfa8110-8f87-49f9-b2a4-06e8d32da244">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HGLG11-teste.csv to HGLG11-teste.csv
# Saving HGLG11-treinamento.csv to HGLG11-treinamento.csv
# downloaded files:
# HGLG11-teste.csv
# HGLG11-treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('HGLG11-treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#               Open         High          Low        Close    Adj Close         Volume
# count  2678.000000  2678.000000  2678.000000  2678.000000  2678.000000    2678.000000
# mean    130.986749   131.813453   129.897470   130.922246   129.972946   14108.421583
# std      25.556473    25.856533    25.379320    25.604233    26.175453   21968.179477
# min      86.998001    87.000000    84.000000    86.500000    85.348480       0.000000
# 25%     111.300003   111.961248   110.500000   111.198997   109.718681    1520.000000
# 50%     125.799504   126.379502   125.000000   125.500000   124.322647    4600.000000
# 75%     150.939999   151.922493   149.240002   150.877498   150.877498   23011.500000
# max     220.949997   221.979996   212.770004   221.139999   221.139999  449301.000000

# %%
base.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**3.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base == 0).sum()
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume       193
# dtype: int64

# %%
#Encontrando os valores nulos
base.loc[base['Volume'] == 0]
# Out:
#             Open        High         Low       Close   Adj Close  Volume
# 0     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 1     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 2     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 3     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 4     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 5     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 6     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 7     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 8     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 9     104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 10    104.399002  104.399002  104.399002  104.399002  103.009201     0.0
# 12    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 13    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 14    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 16    104.401001  104.401001  104.401001  104.401001  103.011185     0.0
# 17    104.401001  104.401001  104.401001  104.401001  103.011185     0.0
# 18    104.401001  104.401001  104.401001  104.401001  103.011185     0.0
# 20    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 21    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 25    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 26    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 27    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 28    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 29    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 36    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 37    104.400002  104.400002  104.400002  104.400002  103.010201     0.0
# 39    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 40    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 41    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 43    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 44    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 45    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 48    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 50    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 57    104.300003  104.300003  104.300003  104.300003  102.911522     0.0
# 63    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 64    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 65    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 66    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 67    104.000000  104.000000  104.000000  104.000000  102.615517     0.0
# 71    106.000000  106.000000  106.000000  106.000000  104.588898     0.0
# 76    106.099998  106.099998  106.099998  106.099998  104.687561     0.0
# 78    107.500000  107.500000  107.500000  107.500000  106.068924     0.0
# 79    107.500000  107.500000  107.500000  107.500000  106.068924     0.0
# 81    106.300003  106.300003  106.300003  106.300003  104.884903     0.0
# 82    106.300003  106.300003  106.300003  106.300003  104.884903     0.0
# 83    106.300003  106.300003  106.300003  106.300003  104.884903     0.0
# 84    106.300003  106.300003  106.300003  106.300003  104.884903     0.0
# 85    106.300003  106.300003  106.300003  106.300003  104.884903     0.0
# 92    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 94    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 96    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 97    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 98    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 99    109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 100   109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 101   109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 102   109.000000  109.000000  109.000000  109.000000  107.548958     0.0
# 106   109.500000  109.500000  109.500000  109.500000  108.042305     0.0
# 108   109.900002  109.900002  109.900002  109.900002  108.436974     0.0
# 109   109.900002  109.900002  109.900002  109.900002  108.436974     0.0
# 110   109.900002  109.900002  109.900002  109.900002  108.436974     0.0
# 112   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 114   111.000000  111.000000  111.000000  111.000000  109.522331     0.0
# 115   111.000000  111.000000  111.000000  111.000000  109.522331     0.0
# 117   115.000000  115.000000  115.000000  115.000000  113.469078     0.0
# 118   115.000000  115.000000  115.000000  115.000000  113.469078     0.0
# 120   115.000000  115.000000  115.000000  115.000000  113.469078     0.0
# 122   115.000000  115.000000  115.000000  115.000000  113.469078     0.0
# 123   115.000000  115.000000  115.000000  115.000000  113.469078     0.0
# 128   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 129   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 130   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 131   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 133   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 134   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 135   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 136   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 137   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 138   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 139   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 140   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 141   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 142   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 143   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 144   117.000000  117.000000  117.000000  117.000000  115.442459     0.0
# 147   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 148   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 149   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 150   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 151   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 152   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 153   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 154   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 155   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 156   112.599998  112.599998  112.599998  112.599998  111.101028     0.0
# 159   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 160   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 170   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 172   116.000000  116.000000  116.000000  116.000000  114.455772     0.0
# 174   116.000000  116.000000  116.000000  116.000000  114.455772     0.0
# 189   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 191   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 193   112.000000  112.000000  112.000000  112.000000  110.509018     0.0
# 195   112.099998  112.099998  112.099998  112.099998  110.607689     0.0
# 198   111.500000  111.500000  111.500000  111.500000  110.015671     0.0
# 202   112.800003  112.800003  112.800003  112.800003  111.298370     0.0
# 205   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 206   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 207   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 208   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 209   116.999001  116.999001  116.999001  116.999001  115.441475     0.0
# 211   116.000000  116.000000  116.000000  116.000000  114.455772     0.0
# 212   116.000000  116.000000  116.000000  116.000000  114.455772     0.0
# 218   115.500000  115.500000  115.500000  115.500000  113.962425     0.0
# 230   119.500000  119.500000  119.500000  119.500000  117.909180     0.0
# 232   121.899002  121.899002  121.899002  121.899002  120.276245     0.0
# 236   122.000000  122.000000  122.000000  122.000000  120.375900     0.0
# 239   116.600998  116.600998  116.600998  116.600998  115.048767     0.0
# 240   116.600998  116.600998  116.600998  116.600998  115.048767     0.0
# 244   123.000000  123.000000  123.000000  123.000000  121.362587     0.0
# 246   123.000000  123.000000  123.000000  123.000000  121.362587     0.0
# 250   124.000000  124.000000  124.000000  124.000000  122.349266     0.0
# 260   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 262   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 267   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 268   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 273   128.000000  128.000000  128.000000  128.000000  126.296021     0.0
# 275   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 277   125.500000  125.500000  125.500000  125.500000  123.829300     0.0
# 280   128.000000  128.000000  128.000000  128.000000  126.296021     0.0
# 287   127.999001  127.999001  127.999001  127.999001  126.295036     0.0
# 290   126.000000  126.000000  126.000000  126.000000  124.322647     0.0
# 294   127.500000  127.500000  127.500000  127.500000  125.802673     0.0
# 295   127.500000  127.500000  127.500000  127.500000  125.802673     0.0
# 301   127.000000  127.000000  127.000000  127.000000  125.309334     0.0
# 309   126.000000  126.000000  126.000000  126.000000  124.322647     0.0
# 328   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 329   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 331   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 332   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 342   135.000000  135.000000  135.000000  135.000000  133.202835     0.0
# 343   135.000000  135.000000  135.000000  135.000000  133.202835     0.0
# 357   131.488998  131.488998  131.488998  131.488998  129.738571     0.0
# 360   131.399994  131.399994  131.399994  131.399994  129.650757     0.0
# 365   130.899002  130.899002  130.899002  130.899002  129.156433     0.0
# 367   130.899994  130.899994  130.899994  130.899994  129.157410     0.0
# 375   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 380   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 386   129.500000  129.500000  129.500000  129.500000  127.776047     0.0
# 391   128.000000  128.000000  128.000000  128.000000  126.296021     0.0
# 399   127.000000  127.000000  127.000000  127.000000  125.309334     0.0
# 402   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 403   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 406   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 407   130.000000  130.000000  130.000000  130.000000  128.269394     0.0
# 409   129.899994  129.899994  129.899994  129.899994  128.170731     0.0
# 410   129.899994  129.899994  129.899994  129.899994  128.170731     0.0
# 412   125.599998  125.599998  125.599998  125.599998  123.927971     0.0
# 413   125.599998  125.599998  125.599998  125.599998  123.927971     0.0
# 420   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 425   120.000000  120.000000  120.000000  120.000000  118.402519     0.0
# 445   125.000000  125.000000  125.000000  125.000000  123.335953     0.0
# 457   129.800003  129.800003  129.800003  129.800003  128.072067     0.0
# 530   131.000000  131.000000  131.000000  131.000000  129.256088     0.0
# 538   129.649994  129.649994  129.649994  129.649994  127.924057     0.0
# 898   111.000000  111.000000  111.000000  111.000000  109.522331     0.0
# 908   107.500000  107.500000  107.500000  107.500000  106.068924     0.0
# 1555  124.900002  124.900002  124.900002  124.900002  123.237289     0.0
# 1615  126.419998  126.419998  126.419998  126.419998  124.737053     0.0
# 1640  130.009995  130.009995  130.009995  130.009995  128.279266     0.0
# 1655  125.656998  125.656998  125.656998  125.656998  124.830681     0.0
# 1664  131.500000  131.500000  131.500000  131.500000  130.635269     0.0
# 1667  131.300003  131.300003  131.300003  131.300003  130.436584     0.0
# 1692  129.300003  129.300003  129.300003  129.300003  129.300003     0.0
# 1696  134.300003  134.300003  134.300003  134.300003  134.300003     0.0
# 1714  130.005005  130.005005  130.005005  130.005005  130.005005     0.0
# 1770  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1771  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1772  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1773  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1774  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1775  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1776  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1777  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1778  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1779  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1780  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1781  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1782  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1783  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1784  117.000000  117.000000  117.000000  117.000000  117.000000     0.0
# 1785  117.000000  117.000000  117.000000  117.000000  117.000000     0.0

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:6].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 2678):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:6])
    preco_real.append(base_treinamento_normalizada[i, 3:4])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 128, return_sequences = True, input_shape = (previsores.shape[1], 6)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 81/81 [==============================] - 6s 20ms/step - loss: 0.0113 - mean_absolute_error: 0.0729
# Epoch 2/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0034 - mean_absolute_error: 0.0417
# Epoch 3/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0398
# Epoch 4/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0027 - mean_absolute_error: 0.0381
# Epoch 5/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0334
# Epoch 6/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0344
# Epoch 7/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0315
# Epoch 8/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0296
# Epoch 9/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0305
# Epoch 10/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0287
# Epoch 11/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0287
# Epoch 12/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0286
# Epoch 13/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0273
# Epoch 14/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0265
# Epoch 15/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0256
# Epoch 16/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0266
# Epoch 17/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0256
# Epoch 18/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0248
# Epoch 19/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0258
# Epoch 20/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0245
# Epoch 21/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0238
# Epoch 22/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0241
# Epoch 23/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0010 - mean_absolute_error: 0.0237
# Epoch 24/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.6723e-04 - mean_absolute_error: 0.0229
# Epoch 25/600
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0010 - mean_absolute_error: 0.0231
# Epoch 26/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.7793e-04 - mean_absolute_error: 0.0232
# Epoch 27/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.8708e-04 - mean_absolute_error: 0.0232
# Epoch 28/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.7893e-04 - mean_absolute_error: 0.0230
# Epoch 29/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.5482e-04 - mean_absolute_error: 0.0224
# Epoch 30/600
# 81/81 [==============================] - 1s 18ms/step - loss: 9.2305e-04 - mean_absolute_error: 0.0223
# Epoch 31/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.7670e-04 - mean_absolute_error: 0.0217
# Epoch 32/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.6798e-04 - mean_absolute_error: 0.0218
# Epoch 33/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.8432e-04 - mean_absolute_error: 0.0219
# Epoch 34/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.7750e-04 - mean_absolute_error: 0.0220
# Epoch 35/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.4662e-04 - mean_absolute_error: 0.0215
# Epoch 36/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.8950e-04 - mean_absolute_error: 0.0221
# Epoch 37/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.9698e-04 - mean_absolute_error: 0.0208
# Epoch 38/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.9023e-04 - mean_absolute_error: 0.0209
# Epoch 39/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.1625e-04 - mean_absolute_error: 0.0208
# Epoch 40/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.3836e-04 - mean_absolute_error: 0.0217
# Epoch 41/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.0112e-04 - mean_absolute_error: 0.0208
# Epoch 42/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.5275e-04 - mean_absolute_error: 0.0204
# Epoch 43/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.4299e-04 - mean_absolute_error: 0.0203
# Epoch 44/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.5473e-04 - mean_absolute_error: 0.0206
# Epoch 45/600
# 81/81 [==============================] - 1s 18ms/step - loss: 8.1026e-04 - mean_absolute_error: 0.0214
# Epoch 46/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.3979e-04 - mean_absolute_error: 0.0201
# Epoch 47/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.7022e-04 - mean_absolute_error: 0.0193
# Epoch 48/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.4346e-04 - mean_absolute_error: 0.0202
# Epoch 49/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.9290e-04 - mean_absolute_error: 0.0210
# Epoch 50/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.6563e-04 - mean_absolute_error: 0.0203
# Epoch 51/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.2334e-04 - mean_absolute_error: 0.0199
# Epoch 52/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.0677e-04 - mean_absolute_error: 0.0198
# Epoch 53/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.0046e-04 - mean_absolute_error: 0.0196
# Epoch 54/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.0906e-04 - mean_absolute_error: 0.0201
# Epoch 55/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.9515e-04 - mean_absolute_error: 0.0196
# Epoch 56/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.1911e-04 - mean_absolute_error: 0.0196
# Epoch 57/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.7493e-04 - mean_absolute_error: 0.0193
# Epoch 58/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.9079e-04 - mean_absolute_error: 0.0211
# Epoch 59/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.7464e-04 - mean_absolute_error: 0.0196
# Epoch 60/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5929e-04 - mean_absolute_error: 0.0189
# Epoch 61/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5534e-04 - mean_absolute_error: 0.0190
# Epoch 62/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.0164e-04 - mean_absolute_error: 0.0193
# Epoch 63/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.8915e-04 - mean_absolute_error: 0.0194
# Epoch 64/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.8697e-04 - mean_absolute_error: 0.0197
# Epoch 65/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.6710e-04 - mean_absolute_error: 0.0189
# Epoch 66/600
# 81/81 [==============================] - 1s 18ms/step - loss: 7.2839e-04 - mean_absolute_error: 0.0201
# Epoch 67/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.7993e-04 - mean_absolute_error: 0.0197
# Epoch 68/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5032e-04 - mean_absolute_error: 0.0186
# Epoch 69/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2995e-04 - mean_absolute_error: 0.0188
# Epoch 70/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1111e-04 - mean_absolute_error: 0.0185
# Epoch 71/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2618e-04 - mean_absolute_error: 0.0187
# Epoch 72/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5957e-04 - mean_absolute_error: 0.0188
# Epoch 73/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2344e-04 - mean_absolute_error: 0.0186
# Epoch 74/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5839e-04 - mean_absolute_error: 0.0189
# Epoch 75/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0146e-04 - mean_absolute_error: 0.0181
# Epoch 76/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.4015e-04 - mean_absolute_error: 0.0189
# Epoch 77/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.4592e-04 - mean_absolute_error: 0.0187
# Epoch 78/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.3870e-04 - mean_absolute_error: 0.0187
# Epoch 79/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.4623e-04 - mean_absolute_error: 0.0188
# Epoch 80/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.9453e-04 - mean_absolute_error: 0.0182
# Epoch 81/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.8104e-04 - mean_absolute_error: 0.0195
# Epoch 82/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.4391e-04 - mean_absolute_error: 0.0187
# Epoch 83/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2664e-04 - mean_absolute_error: 0.0185
# Epoch 84/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2297e-04 - mean_absolute_error: 0.0183
# Epoch 85/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.5088e-04 - mean_absolute_error: 0.0186
# Epoch 86/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0129e-04 - mean_absolute_error: 0.0183
# Epoch 87/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.6763e-04 - mean_absolute_error: 0.0193
# Epoch 88/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7744e-04 - mean_absolute_error: 0.0178
# Epoch 89/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0089e-04 - mean_absolute_error: 0.0183
# Epoch 90/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1380e-04 - mean_absolute_error: 0.0184
# Epoch 91/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6965e-04 - mean_absolute_error: 0.0176
# Epoch 92/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0350e-04 - mean_absolute_error: 0.0182
# Epoch 93/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7735e-04 - mean_absolute_error: 0.0175
# Epoch 94/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0702e-04 - mean_absolute_error: 0.0181
# Epoch 95/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1275e-04 - mean_absolute_error: 0.0181
# Epoch 96/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.2739e-04 - mean_absolute_error: 0.0184
# Epoch 97/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8995e-04 - mean_absolute_error: 0.0180
# Epoch 98/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1235e-04 - mean_absolute_error: 0.0183
# Epoch 99/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7935e-04 - mean_absolute_error: 0.0177
# Epoch 100/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8838e-04 - mean_absolute_error: 0.0178
# Epoch 101/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0582e-04 - mean_absolute_error: 0.0180
# Epoch 102/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8510e-04 - mean_absolute_error: 0.0181
# Epoch 103/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8728e-04 - mean_absolute_error: 0.0177
# Epoch 104/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1299e-04 - mean_absolute_error: 0.0181
# Epoch 105/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0812e-04 - mean_absolute_error: 0.0183
# Epoch 106/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.5728e-04 - mean_absolute_error: 0.0176
# Epoch 107/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.0410e-04 - mean_absolute_error: 0.0183
# Epoch 108/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8480e-04 - mean_absolute_error: 0.0179
# Epoch 109/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.5077e-04 - mean_absolute_error: 0.0173
# Epoch 110/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.4939e-04 - mean_absolute_error: 0.0172
# Epoch 111/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7936e-04 - mean_absolute_error: 0.0173
# Epoch 112/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.9065e-04 - mean_absolute_error: 0.0177
# Epoch 113/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.9191e-04 - mean_absolute_error: 0.0180
# Epoch 114/600
# 81/81 [==============================] - 1s 19ms/step - loss: 5.7495e-04 - mean_absolute_error: 0.0175
# Epoch 115/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.9676e-04 - mean_absolute_error: 0.0178
# Epoch 116/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.5676e-04 - mean_absolute_error: 0.0175
# Epoch 117/600
# 81/81 [==============================] - 1s 18ms/step - loss: 6.1140e-04 - mean_absolute_error: 0.0181
# Epoch 118/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.7806e-04 - mean_absolute_error: 0.0174
# Epoch 119/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.8820e-04 - mean_absolute_error: 0.0175
# Epoch 120/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6861e-04 - mean_absolute_error: 0.0175
# Epoch 121/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6623e-04 - mean_absolute_error: 0.0174
# Epoch 122/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.5298e-04 - mean_absolute_error: 0.0173
# Epoch 123/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6070e-04 - mean_absolute_error: 0.0171
# Epoch 124/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7592e-04 - mean_absolute_error: 0.0176
# Epoch 125/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6195e-04 - mean_absolute_error: 0.0174
# Epoch 126/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.1936e-04 - mean_absolute_error: 0.0169
# Epoch 127/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.3682e-04 - mean_absolute_error: 0.0170
# Epoch 128/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.6346e-04 - mean_absolute_error: 0.0176
# Epoch 129/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.9178e-04 - mean_absolute_error: 0.0176
# Epoch 130/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.6640e-04 - mean_absolute_error: 0.0173
# Epoch 131/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.6196e-04 - mean_absolute_error: 0.0175
# Epoch 132/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.4261e-04 - mean_absolute_error: 0.0171
# Epoch 133/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7720e-04 - mean_absolute_error: 0.0175
# Epoch 134/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.6481e-04 - mean_absolute_error: 0.0175
# Epoch 135/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.3407e-04 - mean_absolute_error: 0.0170
# Epoch 136/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.2573e-04 - mean_absolute_error: 0.0167
# Epoch 137/600
# 81/81 [==============================] - 1s 19ms/step - loss: 5.6062e-04 - mean_absolute_error: 0.0175
# Epoch 138/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6470e-04 - mean_absolute_error: 0.0176
# Epoch 139/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.0507e-04 - mean_absolute_error: 0.0165
# Epoch 140/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.4492e-04 - mean_absolute_error: 0.0170
# Epoch 141/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.2988e-04 - mean_absolute_error: 0.0172
# Epoch 142/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.3721e-04 - mean_absolute_error: 0.0171
# Epoch 143/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.1057e-04 - mean_absolute_error: 0.0167
# Epoch 144/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.3241e-04 - mean_absolute_error: 0.0169
# Epoch 145/600
# 81/81 [==============================] - 1s 18ms/step - loss: 4.7925e-04 - mean_absolute_error: 0.0161
# Epoch 146/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.6417e-04 - mean_absolute_error: 0.0173
# Epoch 147/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7863e-04 - mean_absolute_error: 0.0177
# Epoch 148/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.7815e-04 - mean_absolute_error: 0.0177
# Epoch 149/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.4504e-04 - mean_absolute_error: 0.0172
# Epoch 150/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.0264e-04 - mean_absolute_error: 0.0166
# Epoch 151/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.3437e-04 - mean_absolute_error: 0.0170
# Epoch 152/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.2954e-04 - mean_absolute_error: 0.0171
# Epoch 153/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.3028e-04 - mean_absolute_error: 0.0170
# Epoch 154/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.1081e-04 - mean_absolute_error: 0.0164
# Epoch 155/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.1283e-04 - mean_absolute_error: 0.0166
# Epoch 156/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.0552e-04 - mean_absolute_error: 0.0166
# Epoch 157/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.3600e-04 - mean_absolute_error: 0.0169
# Epoch 158/600
# 81/81 [==============================] - 1s 18ms/step - loss: 4.9222e-04 - mean_absolute_error: 0.0165
# Epoch 159/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.1433e-04 - mean_absolute_error: 0.0166
# Epoch 160/600
# 81/81 [==============================] - 2s 19ms/step - loss: 5.1275e-04 - mean_absolute_error: 0.0166
# Epoch 161/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.2080e-04 - mean_absolute_error: 0.0168
# Epoch 162/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.2190e-04 - mean_absolute_error: 0.0169
# Epoch 163/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.1159e-04 - mean_absolute_error: 0.0168
# Epoch 164/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.0995e-04 - mean_absolute_error: 0.0166
# Epoch 165/600
# 81/81 [==============================] - 1s 18ms/step - loss: 5.4076e-04 - mean_absolute_error: 0.0169
# Epoch 00165: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('HGLG11-teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count   20.000000   20.000000   20.000000   20.000000   20.000000     20.000000
# mean   168.361499  169.544501  167.396999  168.710498  168.710498  29243.450000
# std      1.886642    1.600787    2.183112    2.109643    2.109643   5656.736743
# min    164.000000  166.300003  163.500000  164.000000  164.000000  21968.000000
# 25%    167.859997  168.907497  165.809998  167.849995  167.849995  23840.500000
# 50%    168.619996  169.569999  167.599998  168.834999  168.834999  29569.000000
# 75%    169.449997  170.492504  168.882496  170.044998  170.044998  32313.250000
# max    171.710007  172.970001  171.649994  172.949997  172.949997  41753.000000

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 110): 
    Percorrer_teste.append(entradas[i-90:i, 0:6])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.13293971],
#        [0.13293971],
#        [0.13293971],
#        ...,
#        [0.54240938],
#        [0.54887102],
#        [0.61905828]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[167.00002],
#        [166.51936],
#        [164.45065],
#        [164.26247],
#        [165.34431],
#        [167.48259],
#        [169.17696],
#        [169.78625],
#        [169.84407],
#        [168.50131],
#        [168.55618],
#        [167.78897],
#        [167.36137],
#        [167.72408],
#        [168.03146],
#        [168.57387],
#        [168.60358],
#        [168.98203],
#        [169.40591],
#        [170.64297]], dtype=float32)

# %% [markdown]
# #**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real   Previsoes
# count   20.000000   20.000000
# mean   168.710498  167.901921
# std      2.109643    1.725564
# min    164.000000  164.262466
# 25%    167.849995  167.271034
# 50%    168.834999  168.266388
# 75%    170.044998  169.030758
# max    172.949997  170.642975

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
