# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction-FII/blob/master/Stock-market-prediction-FII-XPLG11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Collecting inflection
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Installing collected packages: inflection
# Successfully installed inflection-0.5.1

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ##**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-5db8e862-ab85-46e5-8949-fe02535a93c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5db8e862-ab85-46e5-8949-fe02535a93c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving XPLG11_teste.csv to XPLG11_teste.csv
# Saving XPLG11_treinamento.csv to XPLG11_treinamento.csv
# downloaded files:
# XPLG11_teste.csv
# XPLG11_treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('XPLG11_treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#              Open        High         Low       Close   Adj Close         Volume
# count  417.000000  417.000000  417.000000  417.000000  417.000000     417.000000
# mean   114.124125  114.869808  113.297482  114.024292  114.024292   60619.966427
# std     12.128416   12.140405   12.159966   12.136299   12.136299   26666.036885
# min     87.160004   88.900002   86.260002   86.910004   86.910004   19807.000000
# 25%    102.830002  103.500000  101.510002  102.580002  102.580002   43892.000000
# 50%    115.010002  115.449997  114.599998  115.000000  115.000000   54789.000000
# 75%    124.980003  126.000000  124.000000  124.570000  124.570000   68168.000000
# max    135.500000  136.669998  135.089996  135.500000  135.500000  201568.000000

# %%
base.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**3.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base == 0).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Encontrando os valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:6].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 417):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:6])
    preco_real.append(base_treinamento_normalizada[i, 3:4])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 128, return_sequences = True, input_shape = (previsores.shape[1], 6)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 11/11 [==============================] - 8s 88ms/step - loss: 0.0395 - mean_absolute_error: 0.1613
# Epoch 2/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0117 - mean_absolute_error: 0.0861
# Epoch 3/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0081 - mean_absolute_error: 0.0704
# Epoch 4/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0076 - mean_absolute_error: 0.0696
# Epoch 5/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0068 - mean_absolute_error: 0.0651
# Epoch 6/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0069 - mean_absolute_error: 0.0655
# Epoch 7/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0070 - mean_absolute_error: 0.0666
# Epoch 8/600
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0068 - mean_absolute_error: 0.0660
# Epoch 9/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0056 - mean_absolute_error: 0.0596
# Epoch 10/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0054 - mean_absolute_error: 0.0577
# Epoch 11/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0051 - mean_absolute_error: 0.0559
# Epoch 12/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0049 - mean_absolute_error: 0.0549
# Epoch 13/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0053 - mean_absolute_error: 0.0562
# Epoch 14/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0066 - mean_absolute_error: 0.0659
# Epoch 15/600
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0057 - mean_absolute_error: 0.0618
# Epoch 16/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0056 - mean_absolute_error: 0.0581
# Epoch 17/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0057 - mean_absolute_error: 0.0583
# Epoch 18/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0047 - mean_absolute_error: 0.0547
# Epoch 19/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0042 - mean_absolute_error: 0.0502
# Epoch 20/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0051 - mean_absolute_error: 0.0563
# Epoch 21/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0046 - mean_absolute_error: 0.0529
# Epoch 22/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0040 - mean_absolute_error: 0.0511
# Epoch 23/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0048 - mean_absolute_error: 0.0550
# Epoch 24/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0042 - mean_absolute_error: 0.0505
# Epoch 25/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0037 - mean_absolute_error: 0.0489
# Epoch 26/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0042 - mean_absolute_error: 0.0516
# Epoch 27/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0047 - mean_absolute_error: 0.0541
# Epoch 28/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0038 - mean_absolute_error: 0.0482
# Epoch 29/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0038 - mean_absolute_error: 0.0505
# Epoch 30/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0040 - mean_absolute_error: 0.0502
# Epoch 31/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0465
# Epoch 32/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0035 - mean_absolute_error: 0.0470
# Epoch 33/600
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0044 - mean_absolute_error: 0.0528
# Epoch 34/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0038 - mean_absolute_error: 0.0498
# Epoch 35/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0035 - mean_absolute_error: 0.0474
# Epoch 36/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0037 - mean_absolute_error: 0.0483
# Epoch 37/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0468
# Epoch 38/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0037 - mean_absolute_error: 0.0475
# Epoch 39/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0041 - mean_absolute_error: 0.0512
# Epoch 40/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0035 - mean_absolute_error: 0.0482
# Epoch 41/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0033 - mean_absolute_error: 0.0456
# Epoch 42/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0035 - mean_absolute_error: 0.0472
# Epoch 43/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0031 - mean_absolute_error: 0.0445
# Epoch 44/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0446
# Epoch 45/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0028 - mean_absolute_error: 0.0418
# Epoch 46/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0024 - mean_absolute_error: 0.0385
# Epoch 47/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0027 - mean_absolute_error: 0.0421
# Epoch 48/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0029 - mean_absolute_error: 0.0436
# Epoch 49/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0036 - mean_absolute_error: 0.0493
# Epoch 50/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0029 - mean_absolute_error: 0.0434
# Epoch 51/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0027 - mean_absolute_error: 0.0414
# Epoch 52/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0028 - mean_absolute_error: 0.0429
# Epoch 53/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0028 - mean_absolute_error: 0.0416
# Epoch 54/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0411
# Epoch 55/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0378
# Epoch 56/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0023 - mean_absolute_error: 0.0373
# Epoch 57/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0026 - mean_absolute_error: 0.0412
# Epoch 58/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0406
# Epoch 59/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0028 - mean_absolute_error: 0.0423
# Epoch 60/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0027 - mean_absolute_error: 0.0401
# Epoch 61/600
# 11/11 [==============================] - 1s 95ms/step - loss: 0.0026 - mean_absolute_error: 0.0415
# Epoch 62/600
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0024 - mean_absolute_error: 0.0391
# Epoch 63/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0019 - mean_absolute_error: 0.0338
# Epoch 64/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0374
# Epoch 65/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0023 - mean_absolute_error: 0.0387
# Epoch 66/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0023 - mean_absolute_error: 0.0373
# Epoch 67/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0023 - mean_absolute_error: 0.0374
# Epoch 68/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0021 - mean_absolute_error: 0.0366
# Epoch 69/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0025 - mean_absolute_error: 0.0396
# Epoch 70/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0024 - mean_absolute_error: 0.0390
# Epoch 71/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0023 - mean_absolute_error: 0.0379
# Epoch 72/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0361
# Epoch 73/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0356
# Epoch 74/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0020 - mean_absolute_error: 0.0354
# Epoch 75/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0350
# Epoch 76/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0019 - mean_absolute_error: 0.0345
# Epoch 77/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0019 - mean_absolute_error: 0.0346
# Epoch 78/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0023 - mean_absolute_error: 0.0382
# Epoch 79/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0358
# Epoch 80/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0021 - mean_absolute_error: 0.0364
# Epoch 81/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0020 - mean_absolute_error: 0.0345
# Epoch 82/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0018 - mean_absolute_error: 0.0331
# Epoch 83/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0019 - mean_absolute_error: 0.0339
# Epoch 84/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0021 - mean_absolute_error: 0.0357
# Epoch 85/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0022 - mean_absolute_error: 0.0373
# Epoch 86/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0022 - mean_absolute_error: 0.0374
# Epoch 87/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0018 - mean_absolute_error: 0.0328
# Epoch 88/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0017 - mean_absolute_error: 0.0329
# Epoch 89/600
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0018 - mean_absolute_error: 0.0340
# Epoch 90/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0017 - mean_absolute_error: 0.0329
# Epoch 91/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0360
# Epoch 92/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0017 - mean_absolute_error: 0.0323
# Epoch 93/600
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0016 - mean_absolute_error: 0.0315
# Epoch 94/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0018 - mean_absolute_error: 0.0324
# Epoch 95/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0309
# Epoch 96/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0015 - mean_absolute_error: 0.0303
# Epoch 97/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0014 - mean_absolute_error: 0.0299
# Epoch 98/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0019 - mean_absolute_error: 0.0350
# Epoch 99/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0019 - mean_absolute_error: 0.0354
# Epoch 100/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0016 - mean_absolute_error: 0.0315
# Epoch 101/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0018 - mean_absolute_error: 0.0337
# Epoch 102/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0307
# Epoch 103/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0018 - mean_absolute_error: 0.0333
# Epoch 104/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0017 - mean_absolute_error: 0.0320
# Epoch 105/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0017 - mean_absolute_error: 0.0316
# Epoch 106/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0017 - mean_absolute_error: 0.0332
# Epoch 107/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0018 - mean_absolute_error: 0.0333
# Epoch 108/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0016 - mean_absolute_error: 0.0314
# Epoch 109/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0017 - mean_absolute_error: 0.0320
# Epoch 110/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0015 - mean_absolute_error: 0.0307
# Epoch 111/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0317
# Epoch 112/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0316
# Epoch 113/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0311
# Epoch 114/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0013 - mean_absolute_error: 0.0289
# Epoch 115/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0013 - mean_absolute_error: 0.0285
# Epoch 116/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0014 - mean_absolute_error: 0.0285
# Epoch 117/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0016 - mean_absolute_error: 0.0309
# Epoch 118/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0311
# Epoch 119/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0312
# Epoch 120/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0312
# Epoch 121/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0300
# Epoch 122/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0015 - mean_absolute_error: 0.0293
# Epoch 123/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0308
# Epoch 124/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0019 - mean_absolute_error: 0.0350
# Epoch 125/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0018 - mean_absolute_error: 0.0324
# Epoch 126/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0019 - mean_absolute_error: 0.0352
# Epoch 127/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0353
# Epoch 128/600
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0017 - mean_absolute_error: 0.0328
# Epoch 129/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0320
# Epoch 130/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0015 - mean_absolute_error: 0.0320
# Epoch 131/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0015 - mean_absolute_error: 0.0313
# Epoch 132/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0016 - mean_absolute_error: 0.0319
# Epoch 133/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0016 - mean_absolute_error: 0.0314
# Epoch 134/600
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0016 - mean_absolute_error: 0.0324
# Epoch 135/600
# 11/11 [==============================] - 1s 90ms/step - loss: 0.0014 - mean_absolute_error: 0.0292
# Epoch 135: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('XPLG11_teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#             Open       High        Low      Close  Adj Close         Volume
# count  18.000000  18.000000  18.000000  18.000000  18.000000      18.000000
# mean   95.867778  96.798333  94.994444  96.059444  96.059444   59881.333333
# std     2.283358   1.884792   2.259300   2.241453   2.241453   29276.336811
# min    91.120003  92.449997  90.870003  91.099998  91.099998   28787.000000
# 25%    95.812500  96.397497  93.287498  95.812500  95.812500   33496.000000
# 50%    96.739998  97.325001  96.250000  96.774997  96.774997   57700.000000
# 75%    97.297503  97.800003  96.549998  97.280001  97.280001   69375.250000
# max    98.000000  99.300003  97.199997  98.910004  98.910004  137652.000000

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 108): 
    Percorrer_teste.append(entradas[i-90:i, 0:6])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.62667214],
#        [0.65013374],
#        [0.65980654],
#        [0.69767435],
#        [0.63161137],
#        [0.64087264],
#        [0.59868282],
#        [0.58633464],
#        [0.611031  ],
#        [0.70158466],
#        [0.7458325 ],
#        [0.7427454 ],
#        [0.7427454 ],
#        [0.75612268],
#        [0.76126777],
#        [0.75920976],
#        [0.88619059],
#        [0.88680798],
#        [0.86622761],
#        [0.8044865 ],
#        [0.77464503],
#        [0.76332577],
#        [0.78390614],
#        [0.80633865],
#        [0.8477054 ],
#        [0.8044865 ],
#        [0.78390614],
#        [0.82115656],
#        [0.82671334],
#        [0.82733073],
#        [0.82033333],
#        [0.83124104],
#        [0.81992178],
#        [0.82095086],
#        [0.82177393],
#        [0.82486103],
#        [0.83473967],
#        [0.82403779],
#        [0.82506687],
#        [0.80551558],
#        [0.76270838],
#        [0.76744178],
#        [0.79316724],
#        [0.78390614],
#        [0.77505658],
#        [0.79357893],
#        [0.8121013 ],
#        [0.79213832],
#        [0.8044865 ],
#        [0.82239149],
#        [0.82568426],
#        [0.8402963 ],
#        [0.86869715],
#        [0.88763105],
#        [0.88763105],
#        [0.88763105],
#        [0.88948353],
#        [0.88680798],
#        [0.85593742],
#        [0.84647031],
#        [0.82136241],
#        [0.82712487],
#        [0.82938873],
#        [0.82300888],
#        [0.85532003],
#        [0.88660228],
#        [0.88680798],
#        [0.88680798],
#        [0.87857595],
#        [0.88680798],
#        [0.8806338 ],
#        [0.88639629],
#        [0.88001641],
#        [0.86416945],
#        [0.87034362],
#        [0.88474982],
#        [0.87960472],
#        [0.87548871],
#        [0.87651779],
#        [0.85593742],
#        [0.86622761],
#        [0.98970982],
#        [0.87260748],
#        [0.87939902],
#        [0.86622761],
#        [0.8857789 ],
#        [0.92241193],
#        [0.93208472],
#        [0.93064426],
#        [0.93002687],
#        [0.93517196],
#        [0.9382589 ],
#        [0.9382589 ],
#        [0.94649092],
#        [0.97921393],
#        [0.98970982],
#        [1.        ],
#        [0.99279675],
#        [0.94649092],
#        [0.9283804 ],
#        [0.88269196],
#        [0.86519853],
#        [0.86622761],
#        [0.8355629 ],
#        [0.83865   ],
#        [0.844824  ],
#        [0.88680798],
#        [0.84605893],
#        [0.8310352 ],
#        [0.83535706],
#        [0.85593742],
#        [0.86602191],
#        [0.84564724],
#        [0.84605893],
#        [0.85140972],
#        [0.86005344],
#        [0.87034362],
#        [0.86272899],
#        [0.86396375],
#        [0.84729371],
#        [0.85964175],
#        [0.84153123],
#        [0.81333606],
#        [0.8188927 ],
#        [0.82259717],
#        [0.74253955],
#        [0.76311992],
#        [0.74253955],
#        [0.70343681],
#        [0.71064007],
#        [0.71496194],
#        [0.69541049],
#        [0.68306229],
#        [0.68676678],
#        [0.6789463 ],
#        [0.69541049],
#        [0.6810043 ],
#        [0.67483012],
#        [0.68470876],
#        [0.68059275],
#        [0.70364266],
#        [0.76332577],
#        [0.69335248],
#        [0.69438158],
#        [0.68367968],
#        [0.68717847],
#        [0.68203338],
#        [0.68182753],
#        [0.69108863],
#        [0.69170603],
#        [0.72216503],
#        [0.73760031],
#        [0.72607534],
#        [0.68717847],
#        [0.72237088],
#        [0.72936812],
#        [0.70158466],
#        [0.69355834],
#        [0.68820738],
#        [0.6978802 ],
#        [0.70775884],
#        [0.69170603],
#        [0.70528913],
#        [0.72689858],
#        [0.73595384],
#        [0.74994849],
#        [0.7427454 ],
#        [0.74871373],
#        [0.74459755],
#        [0.73862939],
#        [0.72628104],
#        [0.71722578],
#        [0.71599086],
#        [0.72422303],
#        [0.69252926],
#        [0.6978802 ],
#        [0.69849757],
#        [0.68820738],
#        [0.69129448],
#        [0.62543736],
#        [0.59045064],
#        [0.5813954 ],
#        [0.58057216],
#        [0.62728951],
#        [0.59868282],
#        [0.59703635],
#        [0.57480951],
#        [0.60444531],
#        [0.59868282],
#        [0.57810246],
#        [0.5492899 ],
#        [0.5472319 ],
#        [0.53488372],
#        [0.53776495],
#        [0.52459354],
#        [0.54105773],
#        [0.55752209],
#        [0.54414481],
#        [0.55731624],
#        [0.56266718],
#        [0.58427663],
#        [0.60238729],
#        [0.59765374],
#        [0.59353773],
#        [0.59868282],
#        [0.59827128],
#        [0.60094668],
#        [0.59930021],
#        [0.59888867],
#        [0.59847698],
#        [0.56781227],
#        [0.5492899 ],
#        [0.56575428],
#        [0.55855117],
#        [0.56966442],
#        [0.57398644],
#        [0.58180692],
#        [0.59415512],
#        [0.57727922],
#        [0.57439799],
#        [0.57810246],
#        [0.59868282],
#        [0.56987027],
#        [0.57604446],
#        [0.57604446],
#        [0.57789661],
#        [0.58263016],
#        [0.57810246],
#        [0.58386494],
#        [0.5783083 ],
#        [0.57480951],
#        [0.57810246],
#        [0.57810246],
#        [0.56781227],
#        [0.55752209],
#        [0.5492899 ],
#        [0.52562246],
#        [0.52047736],
#        [0.52623999],
#        [0.51718459],
#        [0.53591264],
#        [0.53714756],
#        [0.55011313],
#        [0.53694172],
#        [0.55958008],
#        [0.56554841],
#        [0.55711054],
#        [0.55340608],
#        [0.55464086],
#        [0.55752209],
#        [0.55669885],
#        [0.53364878],
#        [0.5381765 ],
#        [0.53714756],
#        [0.52150644],
#        [0.51430336],
#        [0.49639837],
#        [0.47725861],
#        [0.41572337],
#        [0.4161349 ],
#        [0.37188723],
#        [0.37641479],
#        [0.38217741],
#        [0.38649927],
#        [0.38382374],
#        [0.38258896],
#        [0.40646227],
#        [0.4216917 ],
#        [0.47190767],
#        [0.47087876],
#        [0.50586532],
#        [0.53899972],
#        [0.52644569],
#        [0.51841935],
#        [0.52294707],
#        [0.52438767],
#        [0.54105773],
#        [0.53920558],
#        [0.53591264],
#        [0.51636135],
#        [0.5213006 ],
#        [0.4834328 ],
#        [0.47520062],
#        [0.47005552],
#        [0.47005552],
#        [0.45462025],
#        [0.43609787],
#        [0.4095492 ],
#        [0.39287914],
#        [0.40810857],
#        [0.40728534],
#        [0.39287914],
#        [0.35171841],
#        [0.32599295],
#        [0.33113804],
#        [0.33113804],
#        [0.30705905],
#        [0.30664736],
#        [0.31055767],
#        [0.34657332],
#        [0.35068933],
#        [0.35624611],
#        [0.36324337],
#        [0.35418811],
#        [0.3659189 ],
#        [0.36818276],
#        [0.38197157],
#        [0.34554424],
#        [0.35357056],
#        [0.32763942],
#        [0.34348622],
#        [0.30747057],
#        [0.31261567],
#        [0.28380313],
#        [0.27454203],
#        [0.26486923],
#        [0.23050006],
#        [0.25663705],
#        [0.27865804],
#        [0.26013583],
#        [0.25560813],
#        [0.26260537],
#        [0.27145493],
#        [0.27474787],
#        [0.28833083],
#        [0.28689021],
#        [0.28174511],
#        [0.31570276],
#        [0.2920353 ],
#        [0.2920353 ],
#        [0.30006164],
#        [0.30870552],
#        [0.31632015],
#        [0.29327024],
#        [0.31508537],
#        [0.31673184],
#        [0.32084786],
#        [0.3278451 ],
#        [0.32866833],
#        [0.33113804],
#        [0.32846265],
#        [0.32249433],
#        [0.3043835 ],
#        [0.28400898],
#        [0.26672155],
#        [0.25087456],
#        [0.23091159],
#        [0.23358714],
#        [0.18707546],
#        [0.19736565],
#        [0.18090129],
#        [0.18090129],
#        [0.16772988],
#        [0.15414692],
#        [0.15599907],
#        [0.14118118],
#        [0.11916019],
#        [0.08005761],
#        [0.05515522],
#        [0.05124508],
#        [0.06668035],
#        [0.06071202],
#        [0.04918706],
#        [0.04074903],
#        [0.        ],
#        [0.03889687],
#        [0.07285436],
#        [0.080675  ],
#        [0.02037452],
#        [0.02654853],
#        [0.06338741],
#        [0.14076963],
#        [0.19530765],
#        [0.20786168],
#        [0.22000401],
#        [0.21383   ],
#        [0.17678528],
#        [0.17719682],
#        [0.19530765],
#        [0.20148166],
#        [0.19304379],
#        [0.16649509],
#        [0.16711249],
#        [0.16073261],
#        [0.20847907],
#        [0.24758179],
#        [0.26919109],
#        [0.28730192],
#        [0.31878986],
#        [0.26239969],
#        [0.25910675],
#        [0.21177184],
#        [0.21074293],
#        [0.20600936],
#        [0.18831024],
#        [0.21691693],
#        [0.21794602],
#        [0.21177184],
#        [0.22412019],
#        [0.25643137],
#        [0.28689021],
#        [0.30644166],
#        [0.27145493],
#        [0.30026749],
#        [0.28915407],
#        [0.2685737 ],
#        [0.27248403],
#        [0.26116475],
#        [0.2374973 ],
#        [0.24037853],
#        [0.21588802],
#        [0.21094877],
#        [0.20950798],
#        [0.20991969],
#        [0.20642105],
#        [0.21383   ],
#        [0.21383   ]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[98.035286],
#        [97.90792 ],
#        [97.77324 ],
#        [97.611374],
#        [97.43591 ],
#        [97.25498 ],
#        [97.05499 ],
#        [96.82352 ],
#        [96.48667 ],
#        [95.98975 ],
#        [95.273575],
#        [94.42876 ],
#        [93.49411 ],
#        [92.60413 ],
#        [91.848   ],
#        [91.294914],
#        [90.91521 ],
#        [90.67364 ]], dtype=float32)

# %% [markdown]
# #**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real  Previsoes
# count   18.000000  18.000000
# mean    96.059444  95.161443
# std      2.241453   2.667245
# min     91.099998  90.673637
# 25%     95.812500  92.826628
# 50%     96.774997  96.238213
# 75%     97.280001  97.390680
# max     98.910004  98.035286

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
